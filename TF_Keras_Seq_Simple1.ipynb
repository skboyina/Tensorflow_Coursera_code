# %% [markdown]
# <a href="https://colab.research.google.com/github/skboyina/Tensorflow_Coursera_code/blob/main/TF_Keras_Seq_Simple1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.6.0

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
xs = np.array([-1,0,1,2,3,4])
ys = np.array([-3,-1,1,3,5,7])

# %%
model.fit(xs,ys,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0355
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0347
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0340
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0333
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0326
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0320
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0313
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0307
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0300
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0294
# Epoch 11/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0288
# Epoch 12/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0282
# ...

# %%
print(model.predict([10]))
# Out:
# [[18.996904]]
